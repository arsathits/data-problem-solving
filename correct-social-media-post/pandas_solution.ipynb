# %%
import pandas as pd
import sys
import os

# Add project root to path
sys.path.append(r"D:\data-problem-solving")

from db import load_table, engine

# Load your data
input_df = load_table('correct_social_media_post')

# %%
input_df['text'] = input_df['text'].str.replace('Python', 'Pyspark')

final_df = input_df[['comments', 'date', 'id', 'likes', 'platform', 'shares', 'text']].sort_values(by='comments', ascending=True)

# %%
final_df
# Out:
#    comments        date  id  likes   platform  shares  \
# 5         1  2022-03-06   6     60   Facebook       1
# 2         2  2022-03-03   3     30   Facebook       4
# 0         3  2022-03-01   1     10    Twitter       2
# 8         3  2022-03-09   9     90   Facebook       1
# 6         4  2022-03-07   7     70    Twitter       3
# 1         5  2022-03-02   2     20  Instagram       3
# 7         6  2022-03-08   8     80  Instagram       2
# 3         7  2022-03-04   4     40    Twitter       5
# 9         8  2022-03-10  10    100    Twitter       7
# 4         9  2022-03-05   5     50  Instagram       6
#
#                                             text
# 5            Pyspark web development is awesome.
# 2            Pyspark is great for data analysis.
# 0                        This is a Pyspark post.
# 8  Why Pyspark is the best programming language.
# 6                           Pyspark for finance.
# 1                    Another post about Pyspark.
# ...
